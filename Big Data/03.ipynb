# %% [markdown]
# ## Muhammad Rezzha Riamrizal Arsya
# ## 22.21.1545

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('fiba.csv')

# %%
df.head()
# Out:
#       video_id                   channelTitle  \
# 0  qgy45Xma2x4  FIBA - The Basketball Channel
# 1  pPVoESLhVq4  FIBA - The Basketball Channel
# 2  DYU2uGCh58A  FIBA - The Basketball Channel
# 3  uzGImwkIAM4  FIBA - The Basketball Channel
# 4  52cRaA6LMOU  FIBA - The Basketball Channel
#
#                                                title  \
# 0  Brazil vs. Argentina | FIBA South American U18...
# 1  Tango Bourges - Galatasaray | Highlights - Sem...
# 2  SEMI-FINAL: Tango Bourges v Galatasaray | Full...
# 3  Bolivia vs. Paraguay | FIBA South American U18...
# 4  Umana Reyer - CBK Mersin Yenisehir Bld | Highl...
#
#                                          description  \
# 0  Watch the game between Brazil vs. Argentina fr...
# 1  Enjoy the EuroCup Women FINAL FOUR highlights ...
# 2  Watch the Semi-Final game between Tango Bourge...
# 3  Watch the game between Bolivia and Paraguay fr...
# 4  Enjoy the EuroCup Women FINAL FOUR highlights ...
#
# ...

# %%
df.shape
# Out:
# (15910, 13)

# %%
df.columns
# Out:
# Index(['video_id', 'channelTitle', 'title', 'description', 'tags',
#        'publishedAt', 'viewCount', 'likeCount', 'favouriteCount',
#        'commentCount', 'duration', 'definition', 'caption'],
#       dtype='object')

# %%
df.describe()
# Out:
#           viewCount     likeCount  favouriteCount  commentCount
# count  1.591000e+04  15908.000000             0.0  15908.000000
# mean   3.136081e+04    168.829520             NaN     21.805758
# std    1.443056e+05    823.943528             NaN    109.989632
# min    2.000000e+00      0.000000             NaN      0.000000
# 25%    4.897000e+03     26.000000             NaN      1.000000
# 50%    9.664500e+03     55.000000             NaN      3.000000
# 75%    2.209100e+04    131.000000             NaN     10.000000
# max    1.399717e+07  82916.000000             NaN   8561.000000

# %%
df_like = df.sort_values(by=['likeCount'], ascending=False)

# %%
df_like.head()
# Out:
#           video_id                   channelTitle  \
# 14804  zDucvQYlWj4  FIBA - The Basketball Channel
# 3191   NemdMi71n7o  FIBA - The Basketball Channel
# 4870   7_Aull5N9uc  FIBA - The Basketball Channel
# 3499   gdtetu4nnZc  FIBA - The Basketball Channel
# 2390   yEe_xmgKur8  FIBA - The Basketball Channel
#
#                                                    title  \
# 14804  Best Basketball Haka ever? | NZL vs USA | #FIB...
# 3191   Thailand v Indonesia - Full Game - Asia Cup Qu...
# 4870   New Zealand's Haka vs. Giannis led Greece squa...
# 3499   USA 🇺🇸 v Serbia 🇷🇸 - Classic Full Games | FIBA...
# 2390   Korea - Philippines | Highlights - FIBA Asia C...
#
#                                              description  \
# 14804  CRAZY New Zealand's Haka v USA @ 2014 FIBA Bas...
# 3191   Watch the Group A game between Thailand and In...
# 4870   See New Zealand men's team aka the Tall Blacks...
# 3499   Wow! What a classic game today! We show you th...
# ...

# %%
df_like_stats = df_like.iloc[:10]

# %%
df_like_stats
# Out:
#           video_id                   channelTitle  \
# 14804  zDucvQYlWj4  FIBA - The Basketball Channel
# 3191   NemdMi71n7o  FIBA - The Basketball Channel
# 4870   7_Aull5N9uc  FIBA - The Basketball Channel
# 3499   gdtetu4nnZc  FIBA - The Basketball Channel
# 2390   yEe_xmgKur8  FIBA - The Basketball Channel
# 4524   JbiWR0AWKys  FIBA - The Basketball Channel
# 8400   _fU7TVm1PZA  FIBA - The Basketball Channel
# 4634   FCA85PPzwRY  FIBA - The Basketball Channel
# 12642  XBZTPtENQCY  FIBA - The Basketball Channel
# 4941   R1Dy3gONfYY  FIBA - The Basketball Channel
#
#                                                    title  \
# 14804  Best Basketball Haka ever? | NZL vs USA | #FIB...
# 3191   Thailand v Indonesia - Full Game - Asia Cup Qu...
# 4870   New Zealand's Haka vs. Giannis led Greece squa...
# 3499   USA 🇺🇸 v Serbia 🇷🇸 - Classic Full Games | FIBA...
# 2390   Korea - Philippines | Highlights - FIBA Asia C...
# 4524   Team USA outlast the Turkish effort in OT! - F...
# ...

# %%
plt.figure(figsize=(12,7))
plt.bar(df_like_stats['title'],df_like_stats['likeCount'])
plt.title('Jumlah like di video terbanyak')
plt.xlabel('Judul Video')
plt.ylabel('Jumlah like')
plt.xticks(rotation=90, ha="right")

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127482 (\N{REGIONAL INDICATOR SYMBOL LETTER U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127480 (\N{REGIONAL INDICATOR SYMBOL LETTER S}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127479 (\N{REGIONAL INDICATOR SYMBOL LETTER R}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_comment = df.sort_values(by=['commentCount'], ascending=False)

# %%
df_comment.head()
# Out:
#           video_id                   channelTitle  \
# 14804  zDucvQYlWj4  FIBA - The Basketball Channel
# 6544   r8tPSQVnKMI  FIBA - The Basketball Channel
# 6462   hm232lW43qc  FIBA - The Basketball Channel
# 12981  H5Hq6S-cSgo  FIBA - The Basketball Channel
# 4634   FCA85PPzwRY  FIBA - The Basketball Channel
#
#                                                    title  \
# 14804  Best Basketball Haka ever? | NZL vs USA | #FIB...
# 6544   El Salvador v USA - FIBA U16 Women's Americas ...
# 6462   Philippines v Argentina - Highlights - FIBA U1...
# 12981  China v Philippines - Final - Game Highlights ...
# 4634   USA v France - Highlights - Quarter-Finals - F...
#
#                                              description  \
# 14804  CRAZY New Zealand's Haka v USA @ 2014 FIBA Bas...
# 6544   Watch the Group Phase game between El Salvador...
# 6462   Watch the Highlights from the game between Phi...
# 12981  Watch the final highlights of China v Philippi...
# ...

# %%
df_comment_stats = df_comment.iloc[:10]

# %%
df_comment_stats
# Out:
#           video_id                   channelTitle  \
# 14804  zDucvQYlWj4  FIBA - The Basketball Channel
# 6544   r8tPSQVnKMI  FIBA - The Basketball Channel
# 6462   hm232lW43qc  FIBA - The Basketball Channel
# 12981  H5Hq6S-cSgo  FIBA - The Basketball Channel
# 4634   FCA85PPzwRY  FIBA - The Basketball Channel
# 6437   6UdRvPDRL0c  FIBA - The Basketball Channel
# 4941   R1Dy3gONfYY  FIBA - The Basketball Channel
# 4569   lP_mvKD6gQE  FIBA - The Basketball Channel
# 6418   PS0ZkRfjy3o  FIBA - The Basketball Channel
# 2390   yEe_xmgKur8  FIBA - The Basketball Channel
#
#                                                    title  \
# 14804  Best Basketball Haka ever? | NZL vs USA | #FIB...
# 6544   El Salvador v USA - FIBA U16 Women's Americas ...
# 6462   Philippines v Argentina - Highlights - FIBA U1...
# 12981  China v Philippines - Final - Game Highlights ...
# 4634   USA v France - Highlights - Quarter-Finals - F...
# 6437   Philippines v Russia - Highlights - FIBA U19 B...
# ...

# %%
plt.figure(figsize=(12,7))
plt.plot(df_like_stats['title'],df_like_stats['commentCount'])
plt.title('Jumlah komen di video')
plt.xlabel('Judul Video')
plt.ylabel('Jumlah komen')
plt.xticks(rotation=90, ha="right")

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127482 (\N{REGIONAL INDICATOR SYMBOL LETTER U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127480 (\N{REGIONAL INDICATOR SYMBOL LETTER S}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127479 (\N{REGIONAL INDICATOR SYMBOL LETTER R}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
