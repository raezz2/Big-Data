# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 281.4 MB 41 kB/s
# ...
#      |████████████████████████████████| 199 kB 56.3 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845513 sha256=f89a38f7b0b7d89fdb7ad65622ee6457b3175f020e0f204a72b09c775442e866
#   Stored in directory: /root/.cache/pip/wheels/42/59/f5/79a5bf931714dcd201b26025347785f087370a10a3329a899c
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder\
        .master("local")\
        .appName("Colab")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

# %%
df = spark.read.csv("/content/diabetes.csv", header=True)
df.printSchema()
df.show(5)
# Out:
# root
#  |-- Pregnancies: string (nullable = true)
#  |-- Glucose: string (nullable = true)
#  |-- BloodPressure: string (nullable = true)
#  |-- SkinThickness: string (nullable = true)
#  |-- Insulin: string (nullable = true)
#  |-- BMI: string (nullable = true)
#  |-- DiabetesPedigreeFunction: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- Outcome: string (nullable = true)
#
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |          6|    148|           72|           35|      0|33.6|                   0.627| 50|      1|
# |          1|     85|           66|           29|      0|26.6|                   0.351| 31|      0|
# ...

# %%
df.select("Glucose", "Age").show(5)
# Out:
# +-------+---+
# |Glucose|Age|
# +-------+---+
# |    148| 50|
# |     85| 31|
# |    183| 32|
# |     89| 21|
# |    137| 33|
# +-------+---+
# only showing top 5 rows

# %%
df.select("Glucose", "Age").summary().show(8)
# Out:
# +-------+-----------------+------------------+
# |summary|          Glucose|               Age|
# +-------+-----------------+------------------+
# |  count|              768|               768|
# |   mean|     120.89453125|33.240885416666664|
# | stddev|31.97261819513622|11.760231540678689|
# |    min|                0|                21|
# |    25%|             99.0|              24.0|
# |    50%|            117.0|              29.0|
# |    75%|            140.0|              41.0|
# |    max|               99|                81|
# +-------+-----------------+------------------+

# %%
df.rdd.map(lambda :[str(c) for c in row])
# Out:
# PythonRDD[48] at RDD at PythonRDD.scala:53

# %%
df.rdd.map(lambda row: [str(c) for c in row])

for num in Rdd_Reduced.collect():
  print("Age {} has {} Counts" .format(num[0], num[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a3d59d7a79ae> in <module>
#       1 df.rdd.map(lambda row: [str(c) for c in row])
#       2
# ----> 3 for num in Rdd_Reduced.collect():
#       4   print("Age {} has {} Counts" .format(num[0], num[1]))
#
# NameError: name 'Rdd_Reduced' is not defined
